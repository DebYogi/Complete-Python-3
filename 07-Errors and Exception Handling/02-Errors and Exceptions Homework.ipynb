# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Errors and Exceptions Homework

# %% [markdown]
# ### Problem 1
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks.

# %%
for i in ['a','b','c',2,3,4]:
    try:
        print(i**2)
    except TypeError:
        print(f"Cannot square '{i}' because it is not a number.")
        continue
    else:
        print(f"The square of '{i}' is {i**2}.")
    finally:
        print(f"Finished processing '{i}'.")
# Out:
# Cannot square 'a' because it is not a number.
# Finished processing 'a'.
# Cannot square 'b' because it is not a number.
# Finished processing 'b'.
# Cannot square 'c' because it is not a number.
# Finished processing 'c'.
# 4
# The square of '2' is 4.
# Finished processing '2'.
# 9
# The square of '3' is 9.
# Finished processing '3'.
# 16
# The square of '4' is 16.
# Finished processing '4'.

# %% [markdown]
# ### Problem 2
# Handle the exception thrown by the code below by using <code>try</code> and <code>except</code> blocks. Then use a <code>finally</code> block to print 'All Done.'

# %%
x = 5
y = 0
try:
    z = x/y
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
else:
    print(f"The result of {x} divided by {y} is {z}.")
finally:
    print("Execution of the division operation is complete.")
# Out:
# Error: Division by zero is not allowed.
# Execution of the division operation is complete.

# %% [markdown]
# ### Problem 3
# Write a function that asks for an integer and prints the square of it. Use a <code>while</code> loop with a <code>try</code>, <code>except</code>, <code>else</code> block to account for incorrect inputs.

# %%
def ask():
    while True:
        try:
            num = int(input("Please enter a number: "))
        except ValueError:
            print("That's not a valid number. Please try again.")
            continue
        else:
            print(f"Thank you! You entered the number {num}.")
            break
        finally:
            print("Execution of the input operation is complete.")

if __name__ == "__main__":
    ask()

# %%
if __name__ == "__main__":

# %%
from ipywidgets import Text, Button, VBox
from IPython.display import display

text = Text(description="Enter number:")
button = Button(description="Submit")

def on_click(b):
    try:
        num = int(text.value)
        print(f"Thank you! You entered the number {num}.")
    except ValueError:
        print("That's not a valid number. Please try again.")

button.on_click(on_click)
display(VBox([text, button]))

# %% [markdown]
# # Great Job!
